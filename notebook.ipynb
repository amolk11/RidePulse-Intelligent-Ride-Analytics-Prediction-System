# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('dataset/processed/train.csv')
df.head()
# Out:
#      Booking ID       Booking Status   Customer ID Vehicle Type  \
# 0  "CNR4352144"            Completed  "CID8362794"         Bike
# 1  "CNR9147645"            Completed  "CID8300238"      Go Mini
# 2  "CNR1009222"  Cancelled by Driver  "CID2030746"     Go Sedan
# 3  "CNR2740479"  Cancelled by Driver  "CID3231181"         Auto
# 4  "CNR7650148"  Cancelled by Driver  "CID3381661"     Go Sedan
#
#   Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0     Udyog Vihar      Ambience Mall      10.8      38.9
# 1   Basai Dhankot            Madipur       8.5      15.1
# 2     Tughlakabad    Greater Kailash       7.4       NaN
# 3     Palam Vihar  Kherki Daula Toll       5.6       NaN
# 4     Narsinghpur         Pulbangash       6.2       NaN
#
#    Cancelled Rides by Customer Reason for cancelling by Customer  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
#
#    Cancelled Rides by Driver           Driver Cancellation Reason  \
# 0                        NaN                                  NaN
# 1                        NaN                                  NaN
# 2                        1.0  More than permitted people in there
# 3                        1.0        Personal & Car related issues
# 4                        1.0  More than permitted people in there
#
#    Incomplete Rides Incomplete Rides Reason  Booking Value  Ride Distance  \
# 0               NaN                     NaN           99.0          37.98
# 1               NaN                     NaN          114.0          39.29
# 2               NaN                     NaN            NaN            NaN
# 3               NaN                     NaN            NaN            NaN
# 4               NaN                     NaN            NaN            NaN
#
#    Driver Ratings  Customer Rating Payment Method             Datetime
# 0             4.8              4.8           Cash  2024-01-01 00:19:34
# 1             4.2              4.1    Uber Wallet  2024-01-01 01:35:18
# 2             NaN              NaN            NaN  2024-01-01 01:37:50
# 3             NaN              NaN            NaN  2024-01-01 01:48:03
# 4             NaN              NaN            NaN  2024-01-01 01:49:56

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Booking ID                         100000 non-null  str
#  1   Booking Status                     100000 non-null  str
#  2   Customer ID                        100000 non-null  str
#  3   Vehicle Type                       100000 non-null  str
#  4   Pickup Location                    100000 non-null  str
#  5   Drop Location                      100000 non-null  str
#  6   Avg VTAT                           92999 non-null   float64
#  7   Avg CTAT                           67943 non-null   float64
#  8   Cancelled Rides by Customer        6955 non-null    float64
#  9   Reason for cancelling by Customer  6955 non-null    str
#  10  Cancelled Rides by Driver          18101 non-null   float64
#  11  Driver Cancellation Reason         18101 non-null   str
#  12  Incomplete Rides                   5961 non-null    float64
#  13  Incomplete Rides Reason            5961 non-null    str
#  14  Booking Value                      67943 non-null   float64
#  15  Ride Distance                      67943 non-null   float64
#  16  Driver Ratings                     61982 non-null   float64
#  17  Customer Rating                    61982 non-null   float64
#  18  Payment Method                     67943 non-null   str
#  19  Datetime                           100000 non-null  str
# dtypes: float64(9), str(11)
# memory usage: 15.3 MB

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])

cols = ['Datetime'] + [col for col in df.columns if col != 'Datetime']
df = df[cols]
df.sample(5)
# Out:
#                  Datetime    Booking ID         Booking Status   Customer ID  \
# 85706 2024-07-26 19:05:33  "CNR3504598"              Completed  "CID2781801"
# 78452 2024-07-09 10:01:11  "CNR9069664"              Completed  "CID3486184"
# 99317 2024-08-29 11:00:29  "CNR2772977"              Completed  "CID6921726"
# 90092 2024-08-06 12:40:23  "CNR1677739"    Cancelled by Driver  "CID2923548"
# 8135  2024-01-20 17:30:58  "CNR3300822"  Cancelled by Customer  "CID7464516"
#
#       Vehicle Type Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 85706         Auto  Rajouri Garden        Sushant Lok       6.3      17.3
# 78452      Go Mini     Rohini West           Inderlok       7.0      37.8
# 99317     Go Sedan       Seelampur       Indraprastha       8.5      22.8
# 90092         Auto     Rajiv Nagar  Gurgaon Sector 56       3.8       NaN
# 8135          Bike      Badshahpur      Subhash Chowk      14.7       NaN
#
#        Cancelled Rides by Customer  \
# 85706                          NaN
# 78452                          NaN
# 99317                          NaN
# 90092                          NaN
# 8135                           1.0
#
#                   Reason for cancelling by Customer  \
# 85706                                           NaN
# 78452                                           NaN
# 99317                                           NaN
# 90092                                           NaN
# 8135   Driver is not moving towards pickup location
#
#        Cancelled Rides by Driver      Driver Cancellation Reason  \
# 85706                        NaN                             NaN
# 78452                        NaN                             NaN
# 99317                        NaN                             NaN
# 90092                        1.0  The customer was coughing/sick
# 8135                         NaN                             NaN
#
#        Incomplete Rides Incomplete Rides Reason  Booking Value  Ride Distance  \
# 85706               NaN                     NaN          424.0          46.83
# 78452               NaN                     NaN          922.0          34.00
# 99317               NaN                     NaN          375.0           2.50
# 90092               NaN                     NaN            NaN            NaN
# 8135                NaN                     NaN            NaN            NaN
#
#        Driver Ratings  Customer Rating Payment Method
# 85706             4.3              4.4            UPI
# 78452             4.7              4.8    Credit Card
# 99317             4.2              5.0     Debit Card
# 90092             NaN              NaN            NaN
# 8135              NaN              NaN            NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Datetime                           100000 non-null  datetime64[us]
#  1   Booking ID                         100000 non-null  str
#  2   Booking Status                     100000 non-null  str
#  3   Customer ID                        100000 non-null  str
#  4   Vehicle Type                       100000 non-null  str
#  5   Pickup Location                    100000 non-null  str
#  6   Drop Location                      100000 non-null  str
#  7   Avg VTAT                           92999 non-null   float64
#  8   Avg CTAT                           67943 non-null   float64
#  9   Cancelled Rides by Customer        6955 non-null    float64
#  10  Reason for cancelling by Customer  6955 non-null    str
#  11  Cancelled Rides by Driver          18101 non-null   float64
#  12  Driver Cancellation Reason         18101 non-null   str
#  13  Incomplete Rides                   5961 non-null    float64
#  14  Incomplete Rides Reason            5961 non-null    str
#  15  Booking Value                      67943 non-null   float64
#  16  Ride Distance                      67943 non-null   float64
#  17  Driver Ratings                     61982 non-null   float64
#  18  Customer Rating                    61982 non-null   float64
#  19  Payment Method                     67943 non-null   str
# dtypes: datetime64[us](1), float64(9), str(10)
# memory usage: 15.3 MB
